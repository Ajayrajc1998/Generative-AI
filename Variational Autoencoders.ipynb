# %% [markdown]
# ![variational%20autoencoder.png](attachment:variational%20autoencoder.png)

# %% [markdown]
# #### Goal of VAE is to find a distribution $q_{\phi}(z|x)$ of some latent variables which we can sample from $z~q_{\phi}(z|x)$

# %% [markdown]
# ### Restricted Boltzmann Machine (RBM)
# #### Enery function =$-\sum_{i}b_{i}v_{i}-\sum_{i}a_{i}h_{i}-\sum_{ij}v_{i}h_{j}$
